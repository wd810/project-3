# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pymongo import MongoClient

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# %%
# connect to mongo db
client = MongoClient('mongodb://localhost:27017/')
db = client.pokemon_db
# get pokemon base data collection
col_pokemon = db['pokemon_move']
pokemon_base = pd.DataFrame(list(col_pokemon.find())).drop(columns=['_id'])

# %%
# get pokemon raw data collection
col_raw = db['pokemon_data']
pokemon_raw = pd.DataFrame(list(col_raw.find())).drop(columns=['_id'])

# %%
pokemon_elv = pokemon_base.loc[pokemon_base.evol_id != -1]

# %%
pokemon_base.groupby('evolution').mean().drop(columns=['evol_id'])
# Out:
#                 area  avg_acc_power  base_experience  catch_rate_avg  \
# evolution
# 0-0        11.859649      37.512121       212.689394        1.064247
# 2-1        15.120000      32.796278        63.583333        2.421085
# 2-2        10.692308      38.738523       167.812500        1.728700
# 3-1        13.625000      32.331183        57.870968        1.967741
# 3-2        14.169492      34.449892       138.451613        1.266453
# 3-3         3.551724      40.802174       236.793478        0.145172
# n.a        10.454545      38.089596       199.732323        1.591634
#
#            chance_avg  encount_rate_avg     height   move_num  physical_rate  \
# evolution
# 0-0          9.282807          1.206491  16.871212  70.962121      35.247879
# 2-1         12.087933          2.641667   6.616667  65.750000      35.942944
# 2-2          8.450769          1.129060  15.426136  68.488636      38.495000
# 3-1         10.295938          1.893437   5.032258  61.849462      35.409892
# 3-2          8.339153          1.499492   9.376344  62.462366      36.538495
# 3-3          3.305172          0.121724  15.652174  74.369565      39.591739
# n.a          9.933636          2.270000  15.671717  60.535354      35.119192
#
#            special_rate  ...   stat_avg  stat_defense    stat_hp  \
# evolution                ...
# 0-0           25.252500  ...  87.279091     90.704545  82.219697
# 2-1           22.411778  ...  52.428667     54.477778  51.544444
# 2-2           24.175057  ...  79.902102     81.539773  79.960227
# 3-1           22.560000  ...  47.427957     48.225806  46.817204
# 3-2           23.234194  ...  64.641613     67.806452  64.903226
# 3-3           25.141087  ...  86.586522     83.576087  85.750000
# n.a           25.097626  ...  85.438990     85.661616  70.686869
#
#            stat_special-attack  stat_special-defense  stat_speed  \
# evolution
# 0-0                  86.636364             90.439394   81.030303
# 2-1                  48.472222             51.033333   52.522222
# 2-2                  77.977273             78.477273   73.119318
# 3-1                  47.387097             45.709677   44.677419
# 3-2                  64.516129             63.440860   58.731183
# 3-3                  91.086957             85.358696   78.347826
# n.a                  89.580808             85.035354   85.686869
#
#            stat_total_attack  stat_total_defense  status_rate       weight
# evolution
# 0-0               179.280303          181.143939    39.498939  1188.636364
# 2-1               104.994444          105.511111    41.645500   211.166667
# 2-2               166.318182          160.017045    37.330398   833.306818
# 3-1                99.139785           93.935484    42.030645   122.086022
# 3-2               132.967742          131.247312    40.227634   437.043011
# 3-3               186.489130          168.934783    35.267500   921.663043
# n.a               185.565657          170.696970    39.783081   880.803030
#
# [7 rows x 21 columns]

# %%
evl_2 = pokemon_base.loc[pokemon_base.evolution == '2-2'].append(pokemon_base.loc[pokemon_base.evolution == '2-1'])

# %%
pokemon_base.groupby('type').evolution.value_counts()
# Out:
# type      evolution
# bug       2-1           8
#           2-2           4
#           3-1           4
#           0-0           3
#           3-2           3
#           n.a           2
# dark      n.a          12
#           2-2           9
#           2-1           5
#           3-3           5
#           0-0           3
#           3-2           2
#           3-1           1
# dragon    n.a           7
#           0-0           6
#           3-1           6
#           3-2           6
#           3-3           5
#           2-2           4
#           2-1           2
# electric  n.a          19
#           0-0           8
#           3-2           6
#           3-3           6
#           2-1           5
#           2-2           5
#           3-1           5
# fairy     n.a          14
#           0-0          12
#           2-1           7
#                        ..
# poison    n.a           4
#           0-0           3
# psychic   n.a          18
#           0-0          16
#           2-1          14
#           2-2          14
#           3-1           5
#           3-2           5
#           3-3           5
# rock      2-1           6
#           2-2           5
#           0-0           4
#           n.a           4
#           3-1           3
#           3-2           3
#           3-3           3
# steel     n.a          10
#           2-2           9
#           0-0           7
#           3-3           4
#           2-1           3
#           3-1           2
#           3-2           2
# water     2-1          24
#           2-2          18
#           3-1          11
#           n.a          11
#           3-2           9
#           0-0           7
#           3-3           4
# Name: evolution, Length: 125, dtype: int64

# %%
# some pokemon are multi-types
pokemon_type_df = pokemon_raw[['name', 'types']]

# %%
pokemon_type_list = []
for index, row in pokemon_type_df.iterrows():
    name = row[0]
    type_list = row[1]
    '''
     if len(type_list) > 1:
        pokemon = {'name': name, 'type_1': type_list[0]['type']['name'], 'type_2': type_list[1]['type']['name']}
    else:
        pokemon = {'name': name, 'type_1': type_list[0]['type']['name'], 'type_2': 'n.a'}
    
    pokemon_type_list.append(pokemon)
    
    '''
   
pokemon_type_df = pd.DataFrame(pokemon_type_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-104-06e8aa562a43> in <module>()
#       4     type_list = row[1]
#       5     if len(type_list) > 1:
# ----> 6         pokemon = {'name': name, 'type_1': type_list[0]['type']['name'], 'type_2': type_list[1]['type']['name']}
#       7     else:
#       8         pokemon = {'name': name, 'type_1': type_list[0]['type']['name'], 'type_2': 'n.a'}
#
# TypeError: string indices must be integers

# %%
pokemon_base_new = pokemon_base.merge(pokemon_type_df, on='name', how='left')

# %%
pokemon_base_new
# Out:
#      area  avg_acc_power  base_experience  catch_rate_avg  chance_avg  \
# 0     NaN          31.29               64             NaN         NaN
# 1     NaN          27.68              142             NaN         NaN
# 2     NaN          36.34              236             NaN         NaN
# 3     NaN          41.89               62             NaN         NaN
# 4     NaN          40.99              142             NaN         NaN
# 5     NaN          45.77              240             NaN         NaN
# 6     NaN          38.84               63             NaN         NaN
# 7     NaN          41.81              142             NaN         NaN
# 8     NaN          48.27              239             NaN         NaN
# 9    16.0          40.45               39        2.353125        8.35
# 10   13.0          22.45               72        1.584615        8.07
# 11    4.0          32.62              178        0.687500        5.00
# 12   16.0          31.81               39        2.731250       10.28
# 13   13.0          22.45               72        2.246154       10.90
# 14    4.0          36.32              178        0.687500        4.84
# 15   30.0          30.35               50        3.465000       12.58
# 16   20.0          29.69              122        1.462500        6.06
# 17    NaN          33.14              216             NaN         NaN
# 18   56.0          37.48               51        1.417679        9.66
# 19   29.0          40.69              145        2.093103        9.14
# 20   24.0          29.21               52        3.379167       12.57
# 21   22.0          32.97              155        2.222727        7.74
# 22   10.0          36.55               58        3.040000       10.61
# 23   16.0          40.97              157        1.225000        5.09
# 24    7.0          35.74              112        0.735714        4.12
# 25    3.0          39.00              218        0.560000        5.50
# 26   19.0          35.23               60        1.850000        8.99
# 27   20.0          38.50              158        0.750000        8.07
# 28   12.0          31.72               55        2.708333       10.50
# 29   12.0          33.63              128        2.458333       10.00
# ..    ...            ...              ...             ...         ...
# 934   NaN          38.98              168             NaN         NaN
# 935   NaN          33.79              168             NaN         NaN
# 936   NaN          42.76              154             NaN         NaN
# 937   NaN          42.76              154             NaN         NaN
# 938   NaN          42.76              154             NaN         NaN
# 939   NaN          42.76              154             NaN         NaN
# 940   NaN          42.76              154             NaN         NaN
# 941   NaN          42.76              154             NaN         NaN
# 942   NaN          42.76              175             NaN         NaN
# 943   NaN          42.76              175             NaN         NaN
# 944   NaN          42.76              175             NaN         NaN
# 945   NaN          42.76              175             NaN         NaN
# 946   NaN          42.76              175             NaN         NaN
# 947   NaN          42.76              175             NaN         NaN
# 948   NaN          42.76              175             NaN         NaN
# 949   NaN          32.11              167             NaN         NaN
# 950   NaN          31.05              167             NaN         NaN
# 951   NaN          32.11              167             NaN         NaN
# 952   NaN          38.66              270             NaN         NaN
# 953   NaN          40.89              270             NaN         NaN
# 954   NaN          26.63              112             NaN         NaN
# 955   NaN          47.10              149             NaN         NaN
# 956   NaN          30.80              162             NaN         NaN
# 957   NaN          23.89               56             NaN         NaN
# 958   NaN          26.24              170             NaN         NaN
# 959   NaN          34.78              159             NaN         NaN
# 960   NaN          31.43              152             NaN         NaN
# 961   NaN          39.50              306             NaN         NaN
# 962   NaN          39.50              306             NaN         NaN
# 963   NaN          39.50              339             NaN         NaN
#
#      encount_rate_avg  evol_id evolution  height  \
# 0                 NaN      0.0       3-1       7
# 1                 NaN      0.0       3-2      10
# 2                 NaN      0.0       3-3      20
# 3                 NaN      1.0       3-1       6
# 4                 NaN      1.0       3-2      11
# 5                 NaN      1.0       3-3      17
# 6                 NaN      2.0       3-1       5
# 7                 NaN      2.0       3-2      10
# 8                 NaN      2.0       3-3      16
# 9                1.34      3.0       3-1       3
# 10               1.05      3.0       3-2       7
# 11               0.20      3.0       3-3      11
# 12               1.64      4.0       3-1       3
# 13               1.42      4.0       3-2       6
# 14               0.19      4.0       3-3      10
# 15               3.77      5.0       3-1       3
# 16               1.21      5.0       3-2      11
# 17                NaN      5.0       3-3      15
# 18               5.41      6.0       2-1       3
# 19               2.65      6.0       2-2       7
# 20               3.02      7.0       2-1       3
# 21               1.70      7.0       2-2      12
# 22               1.06      8.0       2-1      20
# 23               0.81      8.0       2-2      35
# 24               0.29      9.0       3-2       4
# 25               0.16      9.0       3-3       8
# 26               1.71     10.0       2-1       6
# 27               1.61     10.0       2-2      10
# 28               1.26     11.0       3-1       4
# 29               1.20     11.0       3-2       8
# ..                ...      ...       ...     ...
# 934               NaN     -1.0       n.a      15
# 935               NaN     -1.0       n.a      21
# 936               NaN     -1.0       n.a       3
# 937               NaN     -1.0       n.a       3
# 938               NaN     -1.0       n.a       3
# 939               NaN     -1.0       n.a       3
# 940               NaN     -1.0       n.a       3
# 941               NaN     -1.0       n.a       3
# 942               NaN     -1.0       n.a       3
# 943               NaN     -1.0       n.a       3
# 944               NaN     -1.0       n.a       3
# 945               NaN     -1.0       n.a       3
# 946               NaN     -1.0       n.a       3
# 947               NaN     -1.0       n.a       3
# 948               NaN     -1.0       n.a       3
# 949               NaN     -1.0       n.a       2
# 950               NaN     -1.0       n.a       4
# 951               NaN     -1.0       n.a       4
# 952               NaN     -1.0       n.a      24
# 953               NaN     -1.0       n.a      10
# 954               NaN     -1.0       n.a       4
# 955               NaN     -1.0       n.a      17
# 956               NaN     -1.0       n.a       4
# 957               NaN     -1.0       n.a       5
# 958               NaN     -1.0       n.a       8
# 959               NaN     -1.0       n.a      31
# 960               NaN     -1.0       n.a       6
# 961               NaN     -1.0       n.a      38
# 962               NaN     -1.0       n.a      42
# 963               NaN     -1.0       n.a      75
#
#                                              move_name  ...  stat_hp  \
# 0    [razor-wind, swords-dance, cut, bind, vine-whi...  ...       45
# 1    [swords-dance, cut, bind, vine-whip, headbutt,...  ...       60
# 2    [swords-dance, cut, bind, vine-whip, headbutt,...  ...       80
# 3    [mega-punch, fire-punch, thunder-punch, scratc...  ...       39
# 4    [mega-punch, fire-punch, thunder-punch, scratc...  ...       58
# 5    [mega-punch, fire-punch, thunder-punch, scratc...  ...       78
# 6    [mega-punch, ice-punch, mega-kick, headbutt, t...  ...       44
# 7    [mega-punch, ice-punch, mega-kick, headbutt, t...  ...       59
# 8    [mega-punch, ice-punch, mega-kick, headbutt, t...  ...       79
# 9    [tackle, string-shot, snore, bug-bite, electro...  ...       45
# 10   [string-shot, harden, iron-defense, bug-bite, ...  ...       50
# 11   [razor-wind, gust, whirlwind, take-down, doubl...  ...       60
# 12   [poison-sting, string-shot, bug-bite, electroweb]  ...       40
# 13   [string-shot, harden, iron-defense, bug-bite, ...  ...       45
# 14   [swords-dance, cut, fury-attack, take-down, do...  ...       65
# 15   [razor-wind, gust, wing-attack, whirlwind, fly...  ...       40
# 16   [razor-wind, gust, wing-attack, whirlwind, fly...  ...       63
# 17   [razor-wind, gust, wing-attack, whirlwind, fly...  ...       83
# 18   [cut, headbutt, tackle, body-slam, take-down, ...  ...       30
# 19   [swords-dance, cut, headbutt, tackle, body-sla...  ...       55
# 20   [razor-wind, whirlwind, fly, fury-attack, take...  ...       40
# 21   [razor-wind, whirlwind, fly, fury-attack, take...  ...       65
# 22   [bind, slam, headbutt, body-slam, wrap, take-d...  ...       35
# 23   [bind, headbutt, body-slam, wrap, take-down, d...  ...       60
# 24   [mega-punch, pay-day, thunder-punch, slam, meg...  ...       35
# 25   [mega-punch, pay-day, thunder-punch, mega-kick...  ...       60
# 26   [scratch, swords-dance, cut, sand-attack, head...  ...       50
# 27   [scratch, swords-dance, cut, sand-attack, head...  ...       75
# 28   [scratch, cut, double-kick, headbutt, tackle, ...  ...       55
# 29   [scratch, cut, double-kick, headbutt, horn-dri...  ...       70
# ..                                                 ...  ...      ...
# 934  [swords-dance, hyper-beam, growth, razor-leaf,...  ...       70
# 935  [pound, double-slap, disable, ember, flamethro...  ...       68
# 936  [tackle, take-down, double-edge, hyper-beam, s...  ...       60
# 937  [tackle, take-down, double-edge, hyper-beam, s...  ...       60
# 938  [tackle, take-down, double-edge, hyper-beam, s...  ...       60
# 939  [tackle, take-down, double-edge, hyper-beam, s...  ...       60
# 940  [tackle, take-down, double-edge, hyper-beam, s...  ...       60
# 941  [tackle, take-down, double-edge, hyper-beam, s...  ...       60
# 942  [tackle, take-down, double-edge, hyper-beam, s...  ...       60
# 943  [tackle, take-down, double-edge, hyper-beam, s...  ...       60
# 944  [tackle, take-down, double-edge, hyper-beam, s...  ...       60
# 945  [tackle, take-down, double-edge, hyper-beam, s...  ...       60
# 946  [tackle, take-down, double-edge, hyper-beam, s...  ...       60
# 947  [tackle, take-down, double-edge, hyper-beam, s...  ...       60
# 948  [tackle, take-down, double-edge, hyper-beam, s...  ...       60
# 949  [scratch, swords-dance, surf, hyper-beam, thun...  ...       55
# 950  [scratch, swords-dance, hyper-beam, thunderbol...  ...       55
# 951  [scratch, swords-dance, surf, hyper-beam, thun...  ...       55
# 952  [swords-dance, headbutt, tackle, leer, roar, f...  ...       75
# 953  [sonic-boom, ice-beam, psybeam, aurora-beam, h...  ...       80
# 954  [slam, tail-whip, growl, thunder-shock, thunde...  ...       35
# 955  [swords-dance, thrash, tail-whip, leer, growl,...  ...       60
# 956  [absorb, solar-beam, stun-spore, toxic, psychi...  ...       60
# 957  [sand-attack, tackle, leer, bite, roar, rock-t...  ...       45
# 958  [swords-dance, sand-attack, tackle, thrash, le...  ...       75
# 959  [bite, surf, ice-beam, blizzard, bubble-beam, ...  ...       68
# 960  [tackle, pin-missile, thunder-shock, thunderbo...  ...       65
# 961  [swords-dance, hyper-beam, solar-beam, thunder...  ...       97
# 962  [swords-dance, hyper-beam, solar-beam, thunder...  ...       97
# 963  [swords-dance, hyper-beam, solar-beam, thunder...  ...       97
#
#     stat_special-attack  stat_special-defense  stat_speed  stat_total_attack  \
# 0                    65                    65          45                114
# 1                    80                    80          60                142
# 2                   100                   100          80                182
# 3                    60                    50          65                112
# 4                    80                    65          80                144
# 5                   109                    85         100                193
# 6                    50                    64          43                 98
# 7                    65                    80          58                128
# 8                    85                   105          78                168
# 9                    20                    20          45                 50
# 10                   25                    25          30                 45
# 11                   90                    80          70                135
# 12                   20                    20          50                 55
# 13                   25                    25          35                 50
# 14                   45                    80          75                135
# 15                   35                    35          56                 80
# 16                   50                    50          71                110
# 17                   70                    70         101                150
# 18                   25                    35          72                 81
# 19                   50                    70          97                131
# 20                   31                    31          70                 91
# 21                   61                    61         100                151
# 22                   40                    54          55                100
# 23                   65                    79          80                160
# 24                   50                    50          90                105
# 25                   90                    80         110                180
# 26                   20                    30          40                 95
# 27                   45                    55          65                145
# 28                   40                    40          41                 87
# 29                   55                    55          56                117
# ..                  ...                   ...         ...                ...
# 934                  80                    90          45                185
# 935                 111                    60         117                175
# 936                  60                   100          60                120
# 937                  60                   100          60                120
# 938                  60                   100          60                120
# 939                  60                   100          60                120
# 940                  60                   100          60                120
# 941                  60                   100          60                120
# 942                 100                    60         120                200
# 943                 100                    60         120                200
# 944                 100                    60         120                200
# 945                 100                    60         120                200
# 946                 100                    60         120                200
# 947                 100                    60         120                200
# 948                 100                    60         120                200
# 949                  50                   105          96                140
# 950                  50                   105          96                140
# 951                  50                   105          96                140
# 952                 100                   105          85                210
# 953                 130                   115          65                225
# 954                  50                    50          90                105
# 955                  50                    80          45                130
# 956                  95                    70         124                150
# 957                  30                    40          60                 95
# 958                  55                    65         110                172
# 959                  50                   132          42                120
# 960                  40                    73          96                138
# 961                 113                   109          77                270
# 962                 157                   127          77                270
# 963                 167                    97         129                334
#
#      stat_total_defense  status_rate      type  weight               types
# 0                   114        46.15    poison      69     [poison, grass]
# 1                   143        46.97    poison     130     [poison, grass]
# 2                   183        42.86    poison    1000     [poison, grass]
# 3                    93        27.96      fire      85              [fire]
# 4                   123        28.57      fire     190              [fire]
# 5                   163        26.85    flying     905      [flying, fire]
# 6                   129        30.77     water      90             [water]
# 7                   160        27.63     water     225             [water]
# 8                   205        23.66     water     855             [water]
# 9                    55        20.00       bug      29               [bug]
# 10                   80        60.00       bug      99               [bug]
# 11                  130        44.16    flying     320       [flying, bug]
# 12                   50        25.00    poison      32       [poison, bug]
# 13                   75        60.00    poison     100       [poison, bug]
# 14                  120        33.33    poison     295       [poison, bug]
# 15                   75        42.86    flying      18    [flying, normal]
# 16                  105        44.07    flying     300    [flying, normal]
# 17                  145        42.62    flying     395    [flying, normal]
# 18                   70        28.75    normal      35            [normal]
# 19                  130        30.38    normal     185            [normal]
# 20                   61        41.79    flying      20    [flying, normal]
# 21                  126        41.27    flying     380    [flying, normal]
# 22                   98        35.37    poison      69            [poison]
# 23                  148        32.91    poison     650            [poison]
# 24                   90        32.10  electric      60          [electric]
# 25                  135        31.58  electric     300          [electric]
# 26                  115        27.71    ground     120            [ground]
# 27                  165        27.16    ground     295            [ground]
# 28                   92        37.66    poison      70            [poison]
# 29                  122        33.80    poison     200            [poison]
# ..                  ...          ...       ...     ...                 ...
# 934                 180        38.64     grass     580             [grass]
# 935                 120        40.43      fire     810      [fire, poison]
# 936                 200        44.00    flying     400      [flying, rock]
# 937                 200        44.00    flying     400      [flying, rock]
# 938                 200        44.00    flying     400      [flying, rock]
# 939                 200        44.00    flying     400      [flying, rock]
# 940                 200        44.00    flying     400      [flying, rock]
# 941                 200        44.00    flying     400      [flying, rock]
# 942                 120        44.00    flying       3      [flying, rock]
# 943                 120        44.00    flying       3      [flying, rock]
# 944                 120        44.00    flying       3      [flying, rock]
# 945                 120        44.00    flying       3      [flying, rock]
# 946                 120        44.00    flying       3      [flying, rock]
# 947                 120        44.00    flying       3      [flying, rock]
# 948                 120        44.00    flying       3      [flying, rock]
# 949                 185        48.21     fairy       7      [fairy, ghost]
# 950                 185        49.09     fairy      28      [fairy, ghost]
# 951                 185        48.21     fairy      28      [fairy, ghost]
# 952                 230        42.37  fighting    2075  [fighting, dragon]
# 953                 230        40.38     fairy     805      [fairy, steel]
# 954                  90        42.11  electric      60          [electric]
# 955                 190        28.81     ghost     980       [ghost, fire]
# 956                 130        47.73     fairy      20        [fairy, bug]
# 957                  80        54.55      rock      92              [rock]
# 958                 130        51.28      rock     250              [rock]
# 959                 224        42.50       bug    2175        [bug, water]
# 960                 136        38.64     steel     130   [steel, electric]
# 961                 236        36.07     steel    4600    [steel, psychic]
# 962                 236        36.07     ghost    3500    [ghost, psychic]
# 963                 194        36.07    dragon    2300   [dragon, psychic]
#
# [964 rows x 27 columns]
